# %%
import numpy as np

def cosine_similarity(A, B):
    dot_product = np.dot(A, B)
    magnitude_A = np.linalg.norm(A)
    magnitude_B = np.linalg.norm(B)
    return dot_product / (magnitude_A * magnitude_B)

A = [1, 2, 3]
B = [2, 4, 6]
C = [9, 1, 0]

print(cosine_similarity(A, B))  # 1.0  — very similar
print(cosine_similarity(A, C))  # 0.27 — very different
# Out:
# 1.0
# 0.32465473485552543
