# %%
import numpy as np

def euclidean_distance(A, B):
    return np.linalg.norm(np.array(A) - np.array(B))

A = [1, 2]
B = [4, 6]
C = [1, 3]

print(euclidean_distance(A, B))  # 5.0  — far
print(euclidean_distance(A, C))  # 1.0  — close
# Out:
# 5.0
# 1.0
