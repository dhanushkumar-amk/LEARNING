# %%
import pandas as pd

# %%
df = pd.read_csv('customers-100.csv')
print(df.head())

# %%
# get specific columns

# print(df['City'])
# print(df['City'].head())
print(df[['City', 'Customer Id']].head()) # multiple column select
# Out:
#                 City      Customer Id
# 0       East Leonard  DD37Cf93aecA6Dc
# 1  East Jimmychester  1Ef7b82A4CAAD10
# 2      Isabelborough  6F94879bDAfE5a6
# 3         Bensonview  5Cef8BFA16c5e3c
# 4     West Priscilla  053d585Ab6b3159

# %%
# select row
print(df.loc[1])
# Out:
# Index                                    2
# Customer Id                1Ef7b82A4CAAD10
# First Name                         Preston
# Last Name                           Lozano
# Company                        Vega-Gentry
# City                     East Jimmychester
# Country                           Djibouti
# Phone 1                         5153435776
# Phone 2                   686-620-1820x944
# Email                      vmata@colon.com
# Subscription Date               2021-04-23
# Website              http://www.hobbs.com/
# Name: 1, dtype: object

# %%
print(df.loc[10].Country.capitalize())
# Out:
# Guernsey
