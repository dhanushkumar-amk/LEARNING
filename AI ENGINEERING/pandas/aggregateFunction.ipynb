# %%
import pandas as pd

df = pd.read_json('sample.json')

# %%
# average
print(df.mean(numeric_only=True)) # take only numberic columns
# Out:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64

# %%
print(df.max(numeric_only=True))
# Out:
# sepal.length    7.9
# sepal.width     4.4
# petal.length    6.9
# petal.width     2.5
# dtype: float64

# %%
print(df.min(numeric_only=True))
# Out:
# sepal.length    4.3
# sepal.width     2.0
# petal.length    1.0
# petal.width     0.1
# dtype: float64

# %%
print(df.sum(numeric_only=True))
# Out:
# sepal.length    876.5
# sepal.width     458.6
# petal.length    563.7
# petal.width     179.9
# dtype: float64

# %%
print(df.count())
# Out:
# sepal.length    150
# sepal.width     150
# petal.length    150
# petal.width     150
# variety         150
# dtype: int64

# %%
print(df.mode(numeric_only=True))
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.0          3.0           1.4          0.2
# 1           NaN          NaN           1.5          NaN

# %%
print(df.median(numeric_only=True))
# Out:
# sepal.length    5.80
# sepal.width     3.00
# petal.length    4.35
# petal.width     1.30
# dtype: float64

# %%
print(df['petal.length'].max())
# Out:
# 6.9

# %%
group = df.groupby("variety")
print(group)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001ED53EB8AD0>

# %%
print(group.sum(numeric_only=True))
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa             250.3        171.4          73.1         12.3
# Versicolor         296.8        138.5         213.0         66.3
# Virginica          329.4        148.7         277.6        101.3
